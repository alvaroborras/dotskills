# %% [markdown]
# # NeuroGolf Stack Audit Variant v147 Frank task255 Recovery
#
# Publishes a one-task recovery probe after Biohack displaced the target from score-sort row 1 at the 2026-06-30 14:10Z public Code refresh. This CPU notebook embeds the verified v143 artifact plus Frank's unblocked task255 replacement and writes `/kaggle/working/submission.zip`.

# %%
import json
RECEIPT = '{\n  "base_v143": {\n    "bytes": 524748,\n    "official_public_score": 7179.81,\n    "score_sort_rank_before_submit": 2,\n    "sha256": "df65a4ba1fa85826d5b8c32a0b6743c046c6d71b729e30fa513ad6da40557649",\n    "zip": "work/target_v147_base_output_20260630T1418Z/submission.zip"\n  },\n  "candidate": {\n    "bad_task_count": 0,\n    "base_task_hashes": {\n      "255": "d70ef6905715b23cc05f1c9fa7644a1c30d559ceae05da93a92c952d25639428"\n    },\n    "bytes": 520637,\n    "changed_task_count_vs_v143": 1,\n    "changed_tasks_vs_v143": [\n      255\n    ],\n    "decision": "submit_unblocked_positive_frank_task255_recovery_probe",\n    "profile_rounded_2dp": 7180.12,\n    "profile_total_points": 7180.122723946917,\n    "sha256": "9c8216059b23c7c65e35c0c45ac3e06726f270e1f889ab7d637d42a34c870edb",\n    "task_count": 400,\n    "task_hashes": {\n      "255": "1516c9548dedbc71fcdc31b5dc080a091a258dd5172bcb356de4217dc9fd0bca"\n    },\n    "zip": "work/target_v147_frank_task255_over_v143_20260630T1418Z/submission.zip"\n  },\n  "competition": "neurogolf-2026",\n  "evidence": {\n    "date_watch": "results/target_v147_public_date_watch_20260630T1410Z.json",\n    "full_profile": "results/target_v147_frank_task255_over_v143_20260630T1418Z_full_profile.json",\n    "scan_decision": "results/target_v147_score_leaders_over_v143_20260630T1412Z/decision.json",\n    "scan_summary": "results/target_v147_score_leaders_over_v143_20260630T1412Z/scan_summary.json",\n    "score_watch": "results/target_v147_public_score_watch_20260630T1410Z.json"\n  },\n  "generated_at_utc": "2026-06-30T14:20:00Z",\n  "intent": "recover_score_sort_row1_after_biohack_displaced_target_at_2026-06-30T14:10Z",\n  "run_id": "target_v147_frank_task255_over_v143",\n  "sources": {\n    "frank": "franksunp/neurogolf-consolidated-audit",\n    "frank_last_run_time": "2026-06-30 14:10:23.647000",\n    "source_sha256": "1516c9548dedbc71fcdc31b5dc080a091a258dd5172bcb356de4217dc9fd0bca"\n  },\n  "submit_message": "Public notebook v147 Frank task255 over v143 recovery",\n  "target_kernel": "boristown/neurogolf-stack-audit-variant-v51-7179-45"\n}'
receipt = json.loads(RECEIPT)
print(json.dumps({
    'run_id': receipt['run_id'],
    'sha256': receipt['candidate']['sha256'],
    'bytes': receipt['candidate']['bytes'],
    'changed_tasks': receipt['candidate']['changed_tasks_vs_v143'],
    'profile_rounded_2dp': receipt['candidate']['profile_rounded_2dp'],
    'bad_task_count': receipt['candidate']['bad_task_count'],
}, indent=2))

# %%
import base64
import hashlib
import json
import os
import re
from pathlib import Path
import zipfile

RUN_ID = 'target_v147_frank_task255_over_v143'
EXPECTED_SHA256 = '9c8216059b23c7c65e35c0c45ac3e06726f270e1f889ab7d637d42a34c870edb'
EXPECTED_BYTES = 520637
EXPECTED_TASK_COUNT = 400
TASK_RE = re.compile(r'^task(\d{3})\.onnx$')
WORK = Path(os.environ.get('KAGGLE_WORKING_DIR', '/kaggle/working'))
WORK.mkdir(parents=True, exist_ok=True)

EMBEDDED_SUBMISSION_ZIP_B64 = """

"""
zip_bytes = base64.b64decode(''.join(EMBEDDED_SUBMISSION_ZIP_B64.split()))
actual_sha = hashlib.sha256(zip_bytes).hexdigest()
if actual_sha != EXPECTED_SHA256:
    raise ValueError(f'submission sha mismatch: {actual_sha} != {EXPECTED_SHA256}')
if len(zip_bytes) != EXPECTED_BYTES:
    raise ValueError(f'submission size mismatch: {len(zip_bytes)} != {EXPECTED_BYTES}')
submission_path = WORK / 'submission.zip'
submission_path.write_bytes(zip_bytes)
with zipfile.ZipFile(submission_path) as zf:
    names = sorted(name for name in zf.namelist() if TASK_RE.match(Path(name).name))
if len(names) != EXPECTED_TASK_COUNT:
    raise ValueError(f'task count mismatch: {len(names)} != {EXPECTED_TASK_COUNT}')
manifest = {
    'run_id': RUN_ID,
    'submission_zip': str(submission_path),
    'sha256': actual_sha,
    'bytes': len(zip_bytes),
    'task_count': len(names),
    'base_v143_sha256': 'df65a4ba1fa85826d5b8c32a0b6743c046c6d71b729e30fa513ad6da40557649',
    'changed_tasks_vs_v143': [255],
    'profile_rounded_2dp': 7180.12,
    'profile_total_points': 7180.122723946917,
    'source_public_refs': ['franksunp/neurogolf-consolidated-audit'],
    'task_hashes': {'255': '1516c9548dedbc71fcdc31b5dc080a091a258dd5172bcb356de4217dc9fd0bca'},
}
manifest_path = WORK / 'v147_submission_manifest.json'
manifest_path.write_text(json.dumps(manifest, indent=2, sort_keys=True) + '\n')
print(json.dumps(manifest, indent=2, sort_keys=True))
